# %% [markdown]
# Exemplo de gráfico de linhas para múltiplas séries.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

#mudando o diretório

os.chdir('/home/marta/datascience')

data_df = pd.DataFrame({'x': range(1,11),
                       'y1' : np.random.randn(10),
                       'y2' : np.random.randn(10),
                       'y3' : np.random.randn(10)})

plt.plot('x', 'y1', data = data_df, color = 'blue')
plt.plot('x', 'y2', data = data_df, color = 'red')
plt.plot('x', 'y3', data = data_df, color = 'green')

plt.savefig('gráfico1.pdf', dpi = 300)
plt.legend(labels = ['y1', 'y2', 'y3'])
plt.show()
# Out:
# /tmp/ipykernel_9118/1580914137.py:15: RuntimeWarning: Second argument 'y1' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot('x', 'y1', data = data_df, color = 'blue')
# /tmp/ipykernel_9118/1580914137.py:16: RuntimeWarning: Second argument 'y2' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot('x', 'y2', data = data_df, color = 'red')
# /tmp/ipykernel_9118/1580914137.py:17: RuntimeWarning: Second argument 'y3' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot('x', 'y3', data = data_df, color = 'green')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('/home/marta/datascience/data/data1/Countries.csv')
#dataset.head()
#identificar a quantidade de dados
print("Variáveis:\t {}".format(dataset.shape[0]))
print("Entradas:\t {}\n".format(dataset.shape[1]))
display(dataset.dtypes)
# Out:
# Variáveis:	 170
# Entradas:	 8
# Country              int64
# Name                object
# GDPPC                int64
# Literacy           float64
# InfantMortality    float64
# Agriculture        float64
# Population           int64
# NetMigration       float64
# dtype: object

# %%
# ordenar em ordem decrescente as variáveis por seus valores ausentes
(dataset.isnull().sum() / dataset.shape[0]).sort_values(ascending=False)
# Out:
# Country            0.0
# Name               0.0
# GDPPC              0.0
# Literacy           0.0
# InfantMortality    0.0
# Agriculture        0.0
# Population         0.0
# NetMigration       0.0
# dtype: float64

# %%
# plotar o histograma das variáveis numéricas
dataset.hist(bins=15, figsize=(15,10));

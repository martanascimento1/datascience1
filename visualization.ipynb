# %% [markdown]
# Gráficos

# %%
import matplotlib.pyplot as plt
import numpy as np

#Ex: gráfico de pares (x,y)

x = np.array([-3,-1, 8, 10])
y = np.array ([7, 12, 0 ,5])

plt.plot(x, y)
plt.show()
plt.close()
